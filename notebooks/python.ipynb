# %%
api_ibge = "https://servicodados.ibge.gov.br/api/v3/agregados/5938/periodos/2015|2016|2017|2018|2019|2020|2021|2022|2023/variaveis/37?localidades=N6[N3[33]]|N3[all]"
print(api_ibge)
# Out:
# https://servicodados.ibge.gov.br/api/v3/agregados/5938/periodos/2015|2016|2017|2018|2019|2020|2021|2022|2023/variaveis/37?localidades=N6[N3[33]]|N3[all]

# %%
import requests
import json  # ← Importe o módulo json

print(f"Fazendo requisição à API do IBGE para todos os municípios (2015-2023)...")
response = requests.get(api_ibge)
response.raise_for_status()
data = response.json()

# Exibe o JSON formatado com indentação
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# Fazendo requisição à API do IBGE para todos os municípios (2015-2023)...
# [
#   {
#     "id": "37",
#     "variavel": "Produto Interno Bruto a preços correntes",
#     "unidade": "Mil Reais",
#     "resultados": [
#       {
#         "classificacoes": [],
#         "series": [
#           {
#             "localidade": {
#               "id": "3300100",
#               "nivel": {
#                 "id": "N6",
#                 "nome": "Município"
#               },
#               "nome": "Angra dos Reis - RJ"
#             },
#             "serie": {
#               "2015": "7600989",
#               "2016": "9294025",
#               "2017": "10106295",
#               "2018": "8942168",
#               "2019": "9828660",
#               "2020": "10397760",
#               "2021": "11194157",
#               "2022": "11032725",
#               "2023": "11900498"
#             }
#           },
#           {
#             "localidade": {
#               "id": "3300159",
# ...

# %%
# Importação das bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# Configurações de visualização
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("viridis")
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '{:,.0f}'.format(x) if abs(x) > 1000 else '{:.2f}'.format(x))

# Carregar os dados (substitua pelo caminho do seu arquivo)
df = pd.read_csv('data\ibge_pib_municipios_raw_202608021635.csv')
print(f"Dados carregados: {df.shape[0]:,} registros")
print(f"Período: {df['ano'].min()} a {df['ano'].max()}")
print(f"Municípios: {df['id_municipio'].nunique():,}")
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\i'
# <>:17: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\HP\AppData\Local\Temp\ipykernel_14928\3319349540.py:17: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_csv('data\ibge_pib_municipios_raw_202608021635.csv')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 17
#      13 pd.set_option('display.max_columns', None)
#      14 pd.set_option('display.float_format', lambda x: '{:,.0f}'.format(x) if abs(x) > 1000 else '{:.2f}'.format(x))
#      15
#      16 # Carregar os dados (substitua pelo caminho do seu arquivo)
# ---> 17 df = pd.read_csv('data\ibge_pib_municipios_raw_202608021635.csv')
#      18 print(f"Dados carregados: {df.shape[0]:,} registros")
#      19 print(f"Período: {df['ano'].min()} a {df['ano'].max()}")
#      20 print(f"Municípios: {df['id_municipio'].nunique():,}")
#
# ...
